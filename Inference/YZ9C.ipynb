# %%
# %load_ext autoreload
# %autoreload 2
import warnings
warnings.filterwarnings('ignore')

import sys
sys.path.append('../')
from utils import utils, RWSampler
import Inference as inf

# %%
MIN_EXTREME_VALUE_Threshold = 22.24
Max_EXTREME_VALUE_Threshold = 54.36

# %%
inf.calc_test_blocks_range_values(range = 'low')
# Out:
# [C1] LOW EXTEME RANGE: block name = 112016 | cultivar type 3.0 | mean yield value = 19.94
# [C1] LOW EXTEME RANGE: block name = 262016 | cultivar type 8.0 | mean yield value = 18.38
# [C1] LOW EXTEME RANGE: block name = 622016 | cultivar type 15.0 | mean yield value = 22.00
# [C1] LOW EXTEME RANGE: block name = 902016 | cultivar type 3.0 | mean yield value = 21.28

# %%
inf.calc_test_blocks_range_values(range = 'common')
# Out:
# [C2] COMMON: block name = 52016 | cultivar type 2.0 | mean yield value = 26.48
# [C2] COMMON: block name = 52017 | cultivar type 2.0 | mean yield value = 33.23
# [C2] COMMON: block name = 52018 | cultivar type 2.0 | mean yield value = 33.20
# [C2] COMMON: block name = 112017 | cultivar type 3.0 | mean yield value = 23.25
# [C2] COMMON: block name = 112018 | cultivar type 3.0 | mean yield value = 23.46
# [C2] COMMON: block name = 112019 | cultivar type 3.0 | mean yield value = 27.00
# [C2] COMMON: block name = 252016 | cultivar type 2.0 | mean yield value = 30.64
# [C2] COMMON: block name = 252017 | cultivar type 2.0 | mean yield value = 25.25
# [C2] COMMON: block name = 252018 | cultivar type 2.0 | mean yield value = 25.60
# [C2] COMMON: block name = 252019 | cultivar type 2.0 | mean yield value = 25.94
# [C2] COMMON: block name = 262017 | cultivar type 8.0 | mean yield value = 22.57
# [C2] COMMON: block name = 622017 | cultivar type 15.0 | mean yield value = 26.40
# ...

# %%
inf.calc_test_blocks_range_values(range = 'high')
# Out:
# [C3] High EXTEME RANGE: block name = 1052019 | cultivar type 10.0 | mean yield value = 59.44
# [C3] High EXTEME RANGE: block name = 1812017 | cultivar type 14.0 | mean yield value = 61.26
# [C3] High EXTEME RANGE: block name = 1812018 | cultivar type 14.0 | mean yield value = 61.15
# [C3] High EXTEME RANGE: block name = 1812019 | cultivar type 14.0 | mean yield value = 55.16

# %% [markdown]
# ### YieldZone (9 classes)

# %%
YZ9 = inf.timeseries_spatial_variability(exp_name = '10_lr001_wd05_drop30_yz9')

# %% [markdown]
# #### Block 5

# %%
_ = YZ9.plot(block_name = 5, year = 2016, min_v = 15, max_v = 35)

# %%
_ = YZ9.plot(block_name = 5, year = 2017, min_v = 15, max_v = 35)

# %%
_ = YZ9.plot(block_name = 5, year = 2018, min_v = 15, max_v = 35)

# %% [markdown]
# #### Block 11

# %%
_ = YZ9.plot(block_name = 11, year = 2016, min_v = 10, max_v = 25)

# %%
_ = YZ9.plot(block_name = 11, year = 2017, min_v = 10, max_v = 25)

# %%
_ = YZ9.plot(block_name = 11, year = 2018, min_v = 10, max_v = 25)

# %%
_ = YZ9.plot(block_name = 11, year = 2019, min_v = 10, max_v = 35)

# %% [markdown]
# #### Block 25

# %%
_ = YZ9.plot(block_name = 25, year = 2016, min_v = 15, max_v = 35)

# %%
_ = YZ9.plot(block_name = 25, year = 2017, min_v = 15, max_v = 35)

# %%
_ = YZ9.plot(block_name = 25, year = 2018, min_v = 15, max_v = 35)

# %%
_ = YZ9.plot(block_name = 25, year = 2019, min_v = 15, max_v = 35)

# %% [markdown]
# #### Block 62

# %%
_ = YZ9.plot(block_name = 62, year = 2016, min_v = 15, max_v = 35)

# %%
_ = YZ9.plot(block_name = 62, year = 2017, min_v = 15, max_v = 35)

# %%
_ = YZ9.plot(block_name = 62, year = 2018, min_v = 15, max_v = 35)

# %% [markdown]
# #### Block 90

# %%
_ = YZ9.plot(block_name = 90, year = 2016, min_v = 15, max_v = 35)

# %%
_ = YZ9.plot(block_name = 90, year = 2017, min_v = 15, max_v = 35)

# %%
_ = YZ9.plot(block_name = 90, year = 2018, min_v = 15, max_v = 35)

# %%
_ = YZ9.plot(block_name = 90, year = 2019, min_v = 25, max_v = 45)

# %% [markdown]
# #### Block 105

# %%
_ = YZ9.plot(block_name = 105, year = 2016, min_v = 25, max_v = 45)

# %%
_ = YZ9.plot(block_name = 105, year = 2017, min_v = 35, max_v = 55)

# %%
_ = YZ9.plot(block_name = 105, year = 2018, min_v = 35, max_v = 55)

# %%
_ = YZ9.plot(block_name = 105, year = 2019, min_v = 45, max_v = 65)

# %% [markdown]
# #### Block 114

# %%
_ = YZ9.plot(block_name = 114, year = 2016, min_v = 25, max_v = 45)

# %%
_ = YZ9.plot(block_name = 114, year = 2017, min_v = 25, max_v = 45)

# %%
_ = YZ9.plot(block_name = 114, year = 2018, min_v = 25, max_v = 45)

# %%
_ = YZ9.plot(block_name = 114, year = 2019, min_v = 25, max_v = 45)

# %% [markdown]
# #### Block 135

# %%
_ = YZ9.plot(block_name = 135, year = 2016, min_v = 25, max_v = 45)

# %%
_ = YZ9.plot(block_name = 135, year = 2017, min_v = 25, max_v = 45)

# %%
_ = YZ9.plot(block_name = 135, year = 2018, min_v = 25, max_v = 45)

# %%
_ = YZ9.plot(block_name = 135, year = 2019, min_v = 25, max_v = 45)

# %% [markdown]
# #### Block 178

# %%
_ = YZ9.plot(block_name = 178, year = 2016, min_v = 10, max_v = 45)

# %%
_ = YZ9.plot(block_name = 178, year = 2017, min_v = 10, max_v = 45)

# %%
_ = YZ9.plot(block_name = 178, year = 2018, min_v = 10, max_v = 45)

# %%
_ = YZ9.plot(block_name = 178, year = 2019, min_v = 35, max_v = 55)

# %% [markdown]
# #### Block 181

# %%
_ = YZ9.plot(block_name = 181, year = 2016, min_v = 35, max_v = 55)

# %%
_ = YZ9.plot(block_name = 181, year = 2017, min_v = 45, max_v = 65)

# %%
_ = YZ9.plot(block_name = 181, year = 2018, min_v = 45, max_v = 65)

# %%
_ = YZ9.plot(block_name = 181, year = 2019, min_v = 45, max_v = 65)

# %% [markdown]
# #### Block 186

# %%
_ = YZ9.plot(block_name = 186, year = 2016, min_v = 15, max_v = 35)

# %%
_ = YZ9.plot(block_name = 186, year = 2017, min_v = 15, max_v = 45)

# %%
_ = YZ9.plot(block_name = 186, year = 2018, min_v = 15, max_v = 45)

# %%
_ = YZ9.plot(block_name = 186, year = 2019, min_v = 15, max_v = 45)
